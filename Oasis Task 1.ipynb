# %% [markdown]
# ### Iris Flower Classification

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Akshata Potdar\Desktop\Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.nunique()
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %%
df.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.max(
)
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
df.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
df.drop("Id",axis=1,inplace=True)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### DATS VISUALIZATION

# %% [markdown]
# ### HEAT MAP

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(), annot=True).set(title='Heatmap of Correlated values \n')
sns.diverging_palette(230, 20, l=15, center="dark", as_cmap=True)
plt.show()

# %% [markdown]
# ### HISTOGRAMS

# %%
df.hist(figsize=(10,7))
plt.show()

# %%
sns.pairplot(df, hue = 'Species', palette = 'spring')
plt.show()

# %% [markdown]
# ### BAR PLOTS

# %%
plt.figure(figsize=(13,9))
plt.subplot(2,2,1)
sns.barplot(x="Species",y="SepalLengthCm",data=df,palette ='coolwarm')
plt.subplot(2,2,4)
sns.barplot(x="Species",y="PetalWidthCm",data=df,palette ='spring')
plt.subplot(2,2,2)
sns.barplot(x="Species",y="PetalLengthCm",data=df,palette ='gist_yarg_r')
plt.subplot(2,2,3)
sns.barplot(x="Species",y="SepalWidthCm",data=df,palette ='mako')

plt.show()

# %% [markdown]
# #### PIE PLOT

# %%
fig, ax = plt.subplots(figsize =(8, 7))
#labels
m=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
#title for chart
ax.set_title("\nTYPES OF SPECIES",color="brown")
# Creating color parameters
color = sns.color_palette('dark')
# Creating explode data
explode = (0.0, 0.0, 0.1)
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
# Creating plot
wedges, texts, autotexts = ax.pie(df['Species'].value_counts(),
                                  autopct = "%0.2f",
                                  explode = explode,
                                  labels = m,
                                  shadow = True,
                                  colors = color,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))
# Adding legend
ax.legend(wedges,m,
          title ="Species",
          loc ="center left",
          bbox_to_anchor =(1.2, 0, 0.5, 1))
 
plt.setp(autotexts, size = 8, weight ="bold")

plt.show()

# %% [markdown]
# #### MODEL BUILDING

# %% [markdown]
# Before labelling

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ##### LABEL ENCODING DONE ON 'SPECIES' COLUMN

# %% [markdown]
# 0 = setosa
#
# 1 = Versicolor
#
# 2 = Virginica

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()

# %%
df['Species'] = l.fit_transform(df['Species'])

# %% [markdown]
# After labelling

# %%
df['Species'].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# SPLITTING THE DATA

# %%
x = df.drop(columns = ['Species'])
y = df['Species']

# %%
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Species, dtype: int32

# %% [markdown]
# train and test data
#
# Training data : 80%
#
# Testing data : 20%

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %% [markdown]
# data of training and testing

# %%
x_train.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 90             5.5           2.6            4.4           1.2
# 82             5.8           2.7            3.9           1.2
# 25             5.0           3.0            1.6           0.2
# 99             5.7           2.8            4.1           1.3
# 112            6.8           3.0            5.5           2.1

# %%
x_test.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 60            5.0           2.0            3.5           1.0
# 44            5.1           3.8            1.9           0.4
# 54            6.5           2.8            4.6           1.5
# 5             5.4           3.9            1.7           0.4
# 71            6.1           2.8            4.0           1.3

# %%
y_train.head()
# Out:
# 90     1
# 82     1
# 25     0
# 99     1
# 112    2
# Name: Species, dtype: int32

# %%
y_test.head()
# Out:
# 60    1
# 44    0
# 54    1
# 5     0
# 71    1
# Name: Species, dtype: int32

# %% [markdown]
# dimensions of training and testing data

# %%
x_train.shape
# Out:
# (120, 4)

# %%
x_test.shape
# Out:
# (30, 4)

# %%
y_train.shape
# Out:
# (120,)

# %%
y_test.shape
# Out:
# (30,)

# %% [markdown]
# ## APPROACHES OF MODELS

# %% [markdown]
# #### LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# testing the data of x_test and matches with y_test

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# [1 0 1 0 1 1 0 2 1 2 1 0 2 2 2 1 2 1 0 1 0 1 2 2 2 2 1 0 2 0]

# %%
y_test.head(10)
# Out:
# 60     1
# 44     0
# 54     1
# 5      0
# 71     1
# 106    2
# 36     0
# 145    2
# 80     1
# 105    2
# Name: Species, dtype: int32

# %% [markdown]
# As we can see that y_pred value returned after running
# over x_test results the same as y_test values
#
# Hence , model trained and predicted successfully !!

# %% [markdown]
# ##### confusion_matrix

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[ 8,  0,  0],
#        [ 0, 10,  0],
#        [ 0,  1, 11]], dtype=int64)

# %%
accuracy = accuracy_score(y_test,y_pred)*100
print("Accuracy of the model is ",accuracy)
# Out:
# Accuracy of the model is  96.66666666666667

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
standard_scaler = StandardScaler().fit(x_train)
x_train_std = standard_scaler.transform(x_train)
x_test_std = standard_scaler.transform(x_test)

# %%
model_knn=KNeighborsClassifier(n_neighbors=5)

# %%
model_knn.fit(x_train_std,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# #### testing the data of x_test and matches with y_test

# %%
predict_knn=model_knn.predict(x_test_std)
predict_knn
# Out:
# C:\Users\Akshata Potdar\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# array([1, 0, 1, 0, 1, 1, 0, 2, 1, 2, 1, 0, 2, 2, 2, 1, 2, 1, 0, 1, 0, 1,
#        2, 2, 2, 2, 2, 0, 2, 0])

# %%
y_test.head(10)
# Out:
# 60     1
# 44     0
# 54     1
# 5      0
# 71     1
# 106    2
# 36     0
# 145    2
# 80     1
# 105    2
# Name: Species, dtype: int32

# %% [markdown]
# As we can see that "predict_knn" value returned after
# running over x_test results the same as y_test values
#
# Hence , model trained and predicted successfully !!

# %% [markdown]
# ### Accuracy

# %%
print("Accuracy of the model is ",accuracy_score(y_test,predict_knn)*100)
# Out:
# Accuracy of the model is  93.33333333333333
